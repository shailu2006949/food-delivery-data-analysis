# %% [markdown]
# <a href="https://colab.research.google.com/github/shailu2006949/food-delivery-data-analysis/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = "admin"
password = "1234"
username = input("Enter username: ")
password = input("Enter password: ")
if username == username and password == password:
  print("Login Successful")
else:
  print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful
